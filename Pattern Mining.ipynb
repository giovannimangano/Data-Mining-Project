# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("df_classification.csv", skipinitialspace=True)

# %%
df.head()
# Out:
#          word  length  arousal  valence  dominance  concreteness  familiarity  \
# 0    abattoir       8    4.200    2.864      4.333         5.455        2.382
# 1       abbey       5    3.125    5.781      4.667         5.906        3.324
# 2  abbreviate      10    3.273    5.250      5.235         3.286        5.121
# 3    abdicate       8    4.194    3.767      4.419         3.367        3.971
# 4  abdication      10    3.846    3.880      4.800         3.292        3.097
#
#      aoa  semsize  gender  polysemy  web_corpus_freq
# 0  6.760    4.652   5.391         0         160074.0
# 1  5.177    5.121   3.303         0        4224864.0
# 2  5.543    2.667   3.971         0         140105.0
# 3  6.233    4.679   5.167         0         124123.0
# 4  6.407    5.083   4.571         0         128143.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4668 entries, 0 to 4667
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   word             4668 non-null   object
#  1   length           4668 non-null   int64
#  2   arousal          4668 non-null   float64
#  3   valence          4668 non-null   float64
#  4   dominance        4668 non-null   float64
#  5   concreteness     4668 non-null   float64
#  6   familiarity      4668 non-null   float64
#  7   aoa              4668 non-null   float64
#  8   semsize          4668 non-null   float64
#  9   gender           4668 non-null   float64
#  10  polysemy         4668 non-null   int64
#  11  web_corpus_freq  4668 non-null   float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 437.8+ KB

# %%
#df['AgeBin'] = pd.cut(df['Age'], 4)
df['lengthBin'] = pd.qcut(df['length'], 3)

df['arousalBin'] = pd.qcut(df['arousal'], 4)
df['valenceBin'] = pd.qcut(df['valence'], 4)
df['dominanceBin'] =pd.qcut(df['dominance'], 4)
df['concretenessBin'] = pd.qcut(df['concreteness'], 4)
df['familiarityBin'] = pd.qcut(df['familiarity'], 4)
df['aoaBin'] =pd.qcut(df['aoa'], 4)
df['semsizeBin'] = pd.qcut(df['semsize'], 4)
df['genderBin'] = pd.qcut(df['gender'], 4)
df['web_corpus_freqBin'] = pd.qcut(df['web_corpus_freq'], 4)

# %%
df['arousalBin'] = df['arousalBin'].astype(str) + '_arousal'
df['valenceBin'] = df['valenceBin'].astype(str) + '_valence'
df['dominanceBin'] = df['dominanceBin'].astype(str) + '_dominance'
df['concretenessBin'] = df['concretenessBin'].astype(str) + '_concreteness'
df['familiarityBin'] = df['familiarityBin'].astype(str) + '_familiarity'
df['aoaBin'] = df['aoaBin'].astype(str) + '_aoa'
df['semsizeBin'] = df['semsizeBin'].astype(str) + '_semsize'
df['genderBin'] = df['genderBin'].astype(str) + '_gender'
df['web_corpus_freqBin'] = df['web_corpus_freqBin'].astype(str) + '_web_corpus_freq'
df['lengthBin'] = df['lengthBin'].astype(str) + '_length'

# %%
df.drop(['word','length','arousal', 'valence', 'dominance', 'concreteness', 'familiarity',
        'aoa', 'semsize', 'gender'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4668 entries, 0 to 4667
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   polysemy            4668 non-null   int64
#  1   web_corpus_freq     4668 non-null   float64
#  2   lengthBin           4668 non-null   object
#  3   arousalBin          4668 non-null   object
#  4   valenceBin          4668 non-null   object
#  5   dominanceBin        4668 non-null   object
#  6   concretenessBin     4668 non-null   object
#  7   familiarityBin      4668 non-null   object
#  8   aoaBin              4668 non-null   object
#  9   semsizeBin          4668 non-null   object
#  10  genderBin           4668 non-null   object
#  11  web_corpus_freqBin  4668 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 437.8+ KB

# %%
df
# Out:
#       polysemy  web_corpus_freq            lengthBin              arousalBin  \
# 0            0         160074.0   (7.0, 16.0]_length  (3.846, 4.565]_arousal
# 1            0        4224864.0  (1.999, 5.0]_length  (2.056, 3.846]_arousal
# 2            0         140105.0   (7.0, 16.0]_length  (2.056, 3.846]_arousal
# 3            0         124123.0   (7.0, 16.0]_length  (3.846, 4.565]_arousal
# 4            0         128143.0   (7.0, 16.0]_length  (3.846, 4.565]_arousal
# ...        ...              ...                  ...                     ...
# 4663         0        3192943.0   (7.0, 16.0]_length  (5.419, 8.177]_arousal
# 4664         0       30735412.0  (1.999, 5.0]_length  (3.846, 4.565]_arousal
# 4665         0         655010.0  (1.999, 5.0]_length  (5.419, 8.177]_arousal
# 4666         0       11589578.0  (1.999, 5.0]_length  (5.419, 8.177]_arousal
# 4667         0        1672374.0    (5.0, 7.0]_length  (4.565, 5.419]_arousal
#
#                                valenceBin  \
# 0     (1.0290000000000001, 4.094]_valence
# 1                  (5.286, 6.088]_valence
# 2                  (4.094, 5.286]_valence
# 3     (1.0290000000000001, 4.094]_valence
# 4     (1.0290000000000001, 4.094]_valence
# ...                                   ...
# 4663               (4.094, 5.286]_valence
# 4664               (4.094, 5.286]_valence
# 4665               (6.088, 8.647]_valence
# 4666               (6.088, 8.647]_valence
# 4667               (5.286, 6.088]_valence
#
#                                dominanceBin              concretenessBin  \
# 0     (1.9400000000000002, 4.529]_dominance  (4.471, 5.971]_concreteness
# 1                  (4.529, 5.125]_dominance  (4.471, 5.971]_concreteness
# 2                    (5.125, 5.6]_dominance   (3.24, 4.471]_concreteness
# 3     (1.9400000000000002, 4.529]_dominance   (3.24, 4.471]_concreteness
# 4                  (4.529, 5.125]_dominance   (3.24, 4.471]_concreteness
# ...                                     ...                          ...
# 4663                 (5.125, 5.6]_dominance  (5.971, 6.938]_concreteness
# 4664               (4.529, 5.125]_dominance   (1.635, 3.24]_concreteness
# 4665                 (5.6, 8.371]_dominance   (3.24, 4.471]_concreteness
# 4666                 (5.125, 5.6]_dominance  (5.971, 6.938]_concreteness
# 4667               (4.529, 5.125]_dominance   (3.24, 4.471]_concreteness
#
#                                familiarityBin              aoaBin  \
# 0     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 1     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 2                  (4.706, 5.438]_familiarity  (5.152, 6.833]_aoa
# 3     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 4     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# ...                                       ...                 ...
# 4663  (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 4664               (5.969, 6.939]_familiarity   (1.37, 3.118]_aoa
# 4665  (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 4666               (5.438, 5.969]_familiarity   (1.37, 3.118]_aoa
# 4667  (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
#
#                   semsizeBin              genderBin  \
# 0     (4.182, 4.882]_semsize  (4.656, 6.971]_gender
# 1     (4.882, 6.912]_semsize  (0.999, 3.606]_gender
# 2     (1.374, 3.433]_semsize  (3.606, 4.121]_gender
# 3     (4.182, 4.882]_semsize  (4.656, 6.971]_gender
# 4     (4.882, 6.912]_semsize  (4.121, 4.656]_gender
# ...                      ...                    ...
# 4663  (4.882, 6.912]_semsize  (4.656, 6.971]_gender
# 4664  (1.374, 3.433]_semsize  (4.121, 4.656]_gender
# 4665  (1.374, 3.433]_semsize  (0.999, 3.606]_gender
# 4666  (4.182, 4.882]_semsize  (3.606, 4.121]_gender
# 4667  (4.182, 4.882]_semsize  (3.606, 4.121]_gender
#
#                               web_corpus_freqBin
# 0         (12769.999, 1671099.5]_web_corpus_freq
# 1         (1671099.5, 5702981.5]_web_corpus_freq
# 2         (12769.999, 1671099.5]_web_corpus_freq
# 3         (12769.999, 1671099.5]_web_corpus_freq
# 4         (12769.999, 1671099.5]_web_corpus_freq
# ...                                          ...
# 4663      (1671099.5, 5702981.5]_web_corpus_freq
# 4664  (22327049.5, 2022459848.0]_web_corpus_freq
# 4665      (12769.999, 1671099.5]_web_corpus_freq
# 4666     (5702981.5, 22327049.5]_web_corpus_freq
# 4667      (1671099.5, 5702981.5]_web_corpus_freq
#
# [4668 rows x 12 columns]

# %%
polysemy_dict = {0: 'Not polysemic', 1: 'Polysemic'}
df['polysemy'] = df['polysemy'].map(polysemy_dict)

# %%
df
# Out:
#            polysemy  web_corpus_freq            lengthBin  \
# 0     Not polysemic         160074.0   (7.0, 16.0]_length
# 1     Not polysemic        4224864.0  (1.999, 5.0]_length
# 2     Not polysemic         140105.0   (7.0, 16.0]_length
# 3     Not polysemic         124123.0   (7.0, 16.0]_length
# 4     Not polysemic         128143.0   (7.0, 16.0]_length
# ...             ...              ...                  ...
# 4663  Not polysemic        3192943.0   (7.0, 16.0]_length
# 4664  Not polysemic       30735412.0  (1.999, 5.0]_length
# 4665  Not polysemic         655010.0  (1.999, 5.0]_length
# 4666  Not polysemic       11589578.0  (1.999, 5.0]_length
# 4667  Not polysemic        1672374.0    (5.0, 7.0]_length
#
#                   arousalBin                           valenceBin  \
# 0     (3.846, 4.565]_arousal  (1.0290000000000001, 4.094]_valence
# 1     (2.056, 3.846]_arousal               (5.286, 6.088]_valence
# 2     (2.056, 3.846]_arousal               (4.094, 5.286]_valence
# 3     (3.846, 4.565]_arousal  (1.0290000000000001, 4.094]_valence
# 4     (3.846, 4.565]_arousal  (1.0290000000000001, 4.094]_valence
# ...                      ...                                  ...
# 4663  (5.419, 8.177]_arousal               (4.094, 5.286]_valence
# 4664  (3.846, 4.565]_arousal               (4.094, 5.286]_valence
# 4665  (5.419, 8.177]_arousal               (6.088, 8.647]_valence
# 4666  (5.419, 8.177]_arousal               (6.088, 8.647]_valence
# 4667  (4.565, 5.419]_arousal               (5.286, 6.088]_valence
#
#                                dominanceBin              concretenessBin  \
# 0     (1.9400000000000002, 4.529]_dominance  (4.471, 5.971]_concreteness
# 1                  (4.529, 5.125]_dominance  (4.471, 5.971]_concreteness
# 2                    (5.125, 5.6]_dominance   (3.24, 4.471]_concreteness
# 3     (1.9400000000000002, 4.529]_dominance   (3.24, 4.471]_concreteness
# 4                  (4.529, 5.125]_dominance   (3.24, 4.471]_concreteness
# ...                                     ...                          ...
# 4663                 (5.125, 5.6]_dominance  (5.971, 6.938]_concreteness
# 4664               (4.529, 5.125]_dominance   (1.635, 3.24]_concreteness
# 4665                 (5.6, 8.371]_dominance   (3.24, 4.471]_concreteness
# 4666                 (5.125, 5.6]_dominance  (5.971, 6.938]_concreteness
# 4667               (4.529, 5.125]_dominance   (3.24, 4.471]_concreteness
#
#                                familiarityBin              aoaBin  \
# 0     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 1     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 2                  (4.706, 5.438]_familiarity  (5.152, 6.833]_aoa
# 3     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 4     (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# ...                                       ...                 ...
# 4663  (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 4664               (5.969, 6.939]_familiarity   (1.37, 3.118]_aoa
# 4665  (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
# 4666               (5.438, 5.969]_familiarity   (1.37, 3.118]_aoa
# 4667  (1.6460000000000001, 4.706]_familiarity  (5.152, 6.833]_aoa
#
#                   semsizeBin              genderBin  \
# 0     (4.182, 4.882]_semsize  (4.656, 6.971]_gender
# 1     (4.882, 6.912]_semsize  (0.999, 3.606]_gender
# 2     (1.374, 3.433]_semsize  (3.606, 4.121]_gender
# 3     (4.182, 4.882]_semsize  (4.656, 6.971]_gender
# 4     (4.882, 6.912]_semsize  (4.121, 4.656]_gender
# ...                      ...                    ...
# 4663  (4.882, 6.912]_semsize  (4.656, 6.971]_gender
# 4664  (1.374, 3.433]_semsize  (4.121, 4.656]_gender
# 4665  (1.374, 3.433]_semsize  (0.999, 3.606]_gender
# 4666  (4.182, 4.882]_semsize  (3.606, 4.121]_gender
# 4667  (4.182, 4.882]_semsize  (3.606, 4.121]_gender
#
#                               web_corpus_freqBin
# 0         (12769.999, 1671099.5]_web_corpus_freq
# 1         (1671099.5, 5702981.5]_web_corpus_freq
# 2         (12769.999, 1671099.5]_web_corpus_freq
# 3         (12769.999, 1671099.5]_web_corpus_freq
# 4         (12769.999, 1671099.5]_web_corpus_freq
# ...                                          ...
# 4663      (1671099.5, 5702981.5]_web_corpus_freq
# 4664  (22327049.5, 2022459848.0]_web_corpus_freq
# 4665      (12769.999, 1671099.5]_web_corpus_freq
# 4666     (5702981.5, 22327049.5]_web_corpus_freq
# 4667      (1671099.5, 5702981.5]_web_corpus_freq
#
# [4668 rows x 12 columns]

# %% [markdown]
# ## frequent itemset

# %%
baskets = df.values.tolist()

# %%
itemsets = apriori(baskets, target='s', supp=2, zmin=3, report='S')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-186-ddb030c77a43> in <module>
# ----> 1 itemsets = apriori(X, target='s', supp=2, zmin=3, report='S')
#
# NameError: name 'apriori' is not defined

# %%
itemsets = apriori(X, target='s', supp=2, zmin=3, report='S')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-188-ddb030c77a43> in <module>
# ----> 1 itemsets = apriori(X, target='s', supp=2, zmin=3, report='S')
#
# NameError: name 'apriori' is not defined

# %%
itemsets[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-1289b262dd2b> in <module>
# ----> 1 itemsets[:5]
#
# NameError: name 'itemsets' is not defined

# %%
# frequent itemset
itemsets[0][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-190-0508265d8c02> in <module>
#       1 # frequent itemset
# ----> 2 itemsets[0][0]
#
# NameError: name 'itemsets' is not defined

# %%
# support
itemsets[0][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-191-06b8a060e717> in <module>
#       1 # support
# ----> 2 itemsets[0][1]
#
# NameError: name 'itemsets' is not defined

# %%
itemsets = apriori(X, target='m', supp=2, zmin=3, report='S')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-e757e748a831> in <module>
# ----> 1 itemsets = apriori(X, target='m', supp=2, zmin=3, report='S')
#
# NameError: name 'apriori' is not defined

# %%
itemsets[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-193-1289b262dd2b> in <module>
# ----> 1 itemsets[:5]
#
# NameError: name 'itemsets' is not defined

# %%
len_max_it = []
len_cl_it = []
for i in range(2, 20+1):
    max_itemsets = apriori(X, target='m', supp=i, zmin=3)
    cl_itemsets = apriori(X, target='c', supp=i, zmin=3)
    len_max_it.append( len(max_itemsets)  )
    len_cl_it.append( len(cl_itemsets) )
    
plt.plot(len_max_it, label='maximal')
plt.plot(len_cl_it, label='closed')
plt.legend(fontsize=20)
plt.xticks(fontsize=20)
plt.xlabel('%support', fontsize=15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-5764b79a1564> in <module>
#       2 len_cl_it = []
#       3 for i in range(2, 20+1):
# ----> 4     max_itemsets = apriori(X, target='m', supp=i, zmin=3)
#       5     cl_itemsets = apriori(X, target='c', supp=i, zmin=3)
#       6     len_max_it.append( len(max_itemsets)  )
#
# NameError: name 'apriori' is not defined

# %%
filter_1 = []
filter_2 = []
for i in range(2, 20+1):
    max_itemsets = apriori(X, target='m', supp=i, zmin=3)
    
    filter_1.append( len([item for item in max_itemsets if 'Survived' in item[0]])  )
    filter_2.append( len([item for item in max_itemsets if 'Not Survived' in item[0]]) )
    
plt.plot(filter_1, label='w/ Survived')
plt.plot(filter_2, label='w/ Not Survived')
plt.legend(fontsize=20)
plt.xticks(fontsize=20)
plt.xlabel('%support', fontsize=15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-195-4a17d3023fe1> in <module>
#       2 filter_2 = []
#       3 for i in range(2, 20+1):
# ----> 4     max_itemsets = apriori(X, target='m', supp=i, zmin=3)
#       5
#       6     filter_1.append( len([item for item in max_itemsets if 'Survived' in item[0]])  )
#
# NameError: name 'apriori' is not defined

# %% [markdown]
# ## Rules

# %%
rules = apriori(X, target='r', supp=10, zmin=3, conf=60, report='aScl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-197-d8806dbfffbf> in <module>
# ----> 1 rules = apriori(X, target='r', supp=10, zmin=3, conf=60, report='aScl')
#
# NameError: name 'apriori' is not defined

# %%
rules[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-198-305a6db8918c> in <module>
# ----> 1 rules[:5]
#
# NameError: name 'rules' is not defined

# %%
rules[0][0], rules[0][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-199-267e34a86cca> in <module>
# ----> 1 rules[0][0], rules[0][1]
#
# NameError: name 'rules' is not defined

# %%
# asbolute support
rules[0][2]

# support as percentage
rules[0][3]

# confidence
rules[0][4]

# lift
rules[0][5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-200-fba57d5d3eb1> in <module>
#       1 # asbolute support
# ----> 2 rules[0][2]
#       3
#       4 # support as percentage
#       5 rules[0][3]
#
# NameError: name 'rules' is not defined

# %%
for r in rules:
    if r[0] == 'Polysemic':
        print(r)

# %%
print( 'to_predict:', [r for r in rules if r[0] == 'Polysemic'][0][0])
print( 'how?', [r for r in rules if r[0] == 'Polysemic'][0][1])
